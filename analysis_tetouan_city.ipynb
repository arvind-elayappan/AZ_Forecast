# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df= pd.read_csv('Tetuan City power consumption.csv')

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
df.dtypes
# Out:
# DateTime                      object
# Temperature                  float64
# Humidity                     float64
# Wind Speed                   float64
# general diffuse flows        float64
# diffuse flows                float64
# Zone 1 Power Consumption     float64
# Zone 2  Power Consumption    float64
# Zone 3  Power Consumption    float64
# dtype: object

# %%
import eda5_tools as eda
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import eda5_tools as eda
#
# ModuleNotFoundError: No module named 'eda5_tools'

# %%
df_date_index=eda.set_datetime_index(df, 'DateTime')
# Out:
# c:\Users\PRADEEP CHUDASAMA\OneDrive\Desktop\AI_ML Projects\Tetouan_city_consumption\eda5_tools.py:63: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df[datetime_col] = pd.to_datetime(

# %%
eda.clean_column_names(df_date_index)

# %%
df_date_index.shape
# Out:
# (52416, 8)

# %%
eda.summarize_dataframe(df)
# Out:
# ----- 1) SHAPE -----
# (52416, 9)
#
# ----- 2) DTYPES -----
# DateTime                      object
# Temperature                  float64
# Humidity                     float64
# Wind Speed                   float64
# general diffuse flows        float64
# diffuse flows                float64
# Zone 1 Power Consumption     float64
# Zone 2  Power Consumption    float64
# Zone 3  Power Consumption    float64
# dtype: object
#
# ----- 3) INFO -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DateTime                   52416 non-null  object
#  1   Temperature                52416 non-null  float64
#  2   Humidity                   52416 non-null  float64
#  3   Wind Speed                 52416 non-null  float64
#  4   general diffuse flows      52416 non-null  float64
# ...

# %%
eda.get_correlation_matrix(df)
# Out:
#                            Temperature  Humidity  Wind Speed  \
# Temperature                   1.000000 -0.460243    0.477109
# Humidity                     -0.460243  1.000000   -0.135853
# Wind Speed                    0.477109 -0.135853    1.000000
# general diffuse flows         0.460294 -0.468138    0.133733
# diffuse flows                 0.196522 -0.256886   -0.000972
# Zone 1 Power Consumption      0.440221 -0.287421    0.167444
# Zone 2  Power Consumption     0.382428 -0.294961    0.146413
# Zone 3  Power Consumption     0.489527 -0.233022    0.278641
#
#                            general diffuse flows  diffuse flows  \
# Temperature                             0.460294       0.196522
# Humidity                               -0.468138      -0.256886
# Wind Speed                              0.133733      -0.000972
# general diffuse flows                   1.000000       0.564718
# diffuse flows                           0.564718       1.000000
# ...

# %%
eda.plot_correlation_heatmap(df)

# %%
eda.plot_each_daily_aggregation(df_date_index,'sum')

# %%
eda.plot_boxplots(df_date_index)

# %%
# df_date_index=eda.clean_column_names(df_date_index)

# %%
df_date_index.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'general diffuse flows',
#        'diffuse flows', 'Zone 1 Power Consumption', 'Zone 2 Power Consumption',
#        'Zone 3 Power Consumption'],
#       dtype='object')

# %%
eda.plot_pairplot(df_date_index,columns=['Zone 1 Power Consumption', 'Zone 2 Power Consumption', 'Zone 3 Power Consumption'],diag_kind='kde')

# %%
eda.plot_each_daily_aggregation(df_date_index, 'sum')

# %%
eda.plot_each_time_series(df_date_index)

# %%
eda.plot_resampled(df_date_index,
    freq="D",
    how="sum",
    figsize=(12, 6),
    title="Daily Resampled Data",
    xlabel="Date",
    )

# %%
eda.plot_time_series_for_column(df_date_index,
    column="Temperature",
    figsize=(12, 4),
    title="Temperature Over Time",
    xlabel="Date",
    ylabel="Temperature (°C)",
    freq="D",
    how="sum")

# %%
eda.get_correlation_matrix(df_date_index)
# Out:
#                           Temperature  Humidity  Wind Speed  \
# Temperature                  1.000000 -0.460243    0.477109
# Humidity                    -0.460243  1.000000   -0.135853
# Wind Speed                   0.477109 -0.135853    1.000000
# general diffuse flows        0.460294 -0.468138    0.133733
# diffuse flows                0.196522 -0.256886   -0.000972
# Zone 1 Power Consumption     0.440221 -0.287421    0.167444
# Zone 2 Power Consumption     0.382428 -0.294961    0.146413
# Zone 3 Power Consumption     0.489527 -0.233022    0.278641
#
#                           general diffuse flows  diffuse flows  \
# Temperature                            0.460294       0.196522
# Humidity                              -0.468138      -0.256886
# Wind Speed                             0.133733      -0.000972
# general diffuse flows                  1.000000       0.564718
# diffuse flows                          0.564718       1.000000
# ...

# %%
eda.plot_correlation_heatmap()

# %%
# give me the data for hourly consumption for each zone
df_hourly = df_date_index.resample('H').mean()
df_daily = df_date_index.resample('D').mean()
df_monthly = df_date_index.resample('M').mean()
# Out:
# C:\Users\PRADEEP CHUDASAMA\AppData\Local\Temp\ipykernel_32652\3992399753.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_hourly = df_date_index.resample('H').mean()
# C:\Users\PRADEEP CHUDASAMA\AppData\Local\Temp\ipykernel_32652\3992399753.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df_date_index.resample('M').mean()

# %%
df_hourly.head()
# Out:
#                      Temperature   Humidity  Wind Speed  \
# DateTime
# 2017-01-01 00:00:00     6.196833  75.066667    0.081833
# 2017-01-01 01:00:00     5.548833  77.583333    0.082000
# 2017-01-01 02:00:00     5.054333  78.933333    0.082333
# 2017-01-01 03:00:00     5.004333  77.083333    0.082833
# 2017-01-01 04:00:00     5.097667  74.050000    0.082333
#
#                      general diffuse flows  diffuse flows  \
# DateTime
# 2017-01-01 00:00:00               0.063500       0.098833
# 2017-01-01 01:00:00               0.056833       0.112500
# 2017-01-01 02:00:00               0.063000       0.129167
# 2017-01-01 03:00:00               0.059833       0.141000
# 2017-01-01 04:00:00               0.058000       0.122833
#
#                      Zone 1 Power Consumption  Zone 2 Power Consumption  \
# DateTime
# 2017-01-01 00:00:00              29197.974683              18026.747720
# 2017-01-01 01:00:00              24657.215190              16078.419453
# ...

# %%
df_daily
# Out:
#             Temperature   Humidity  Wind Speed  general diffuse flows  \
# DateTime
# 2017-01-01     9.675299  68.519306    0.315146             121.390771
# 2017-01-02    12.476875  71.456319    0.076563             120.404486
# 2017-01-03    12.100000  74.981667    0.076715             120.686014
# 2017-01-04    10.509479  75.459792    0.082417             122.959319
# 2017-01-05    10.866444  71.040486    0.083896             118.749861
# ...                 ...        ...         ...                    ...
# 2017-12-26    11.621840  69.070903    0.083062             106.836687
# 2017-12-27    15.232917  59.445903    0.082028              95.890674
# 2017-12-28    13.662361  62.839375    0.081354             112.620160
# 2017-12-29    12.990486  49.078750    0.078181             122.220021
# 2017-12-30    11.688993  51.361667    0.078174             123.814125
#
#             diffuse flows  Zone 1 Power Consumption  Zone 2 Power Consumption  \
# DateTime
# ...

# %%
eda.plot_correlation_heatmap(df_monthly)

# %%
eda.plot_pairplot(df_daily, columns=['Zone 1 Power Consumption', 'Temperature','Humidity','Wind Speed'], diag_kind='kde')

# %%
# import eda_plotly as eda_p
# !pip install plotly

# %%
eda_p.plotly_pairplot(df_daily, columns=['Zone 1 Power Consumption', 'Temperature', 'Humidity', 'Wind Speed'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 eda_p.plotly_pairplot(df_daily, columns=['Zone 1 Power Consumption', 'Temperature', 'Humidity', 'Wind Speed'])
#
# NameError: name 'eda_p' is not defined

# %%
eda and new additional tools for eda
